# %% [markdown]
# ### Label Encoder

# %%
# !pip install -U numpy #Upgrade numpy to the latest version
from sklearn.preprocessing import LabelEncoder #Import LabelEncoder as before
import pandas as pd #Import pandas as before
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (2.1.3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-8a6878dfdd0f> in <cell line: 2>()
#       1 get_ipython().system('pip install -U numpy #Upgrade numpy to the latest version')
# ----> 2 from sklearn.preprocessing import LabelEncoder #Import LabelEncoder as before
#       3 import pandas as pd #Import pandas as before
#
# /usr/local/lib/python3.10/dist-packages/sklearn/__init__.py in <module>
#      82         _distributor_init,  # noqa: F401
#      83     )
# ---> 84     from .base import clone
#      85     from .utils._show_versions import show_versions
#      86
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in <module>
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/__init__.py in <module>
#       9 from . import _joblib, metadata_routing
#      10 from ._bunch import Bunch
# ---> 11 from ._chunking import gen_batches, gen_even_slices
#      12 from ._estimator_html_repr import estimator_html_repr
#      13
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_chunking.py in <module>
#       6
#       7 from .._config import get_config
# ----> 8 from ._param_validation import Interval, validate_params
#       9
#      10
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in <module>
#      12
#      13 from .._config import config_context, get_config
# ---> 14 from .validation import _is_arraylike_not_scalar
#      15
#      16
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in <module>
#      24 from .. import get_config as _get_config
#      25 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 26 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      27 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#      28 from ._isfinite import FiniteStatus, cy_isfinite
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in <module>
#       9
#      10 from .._config import get_config
# ---> 11 from .fixes import parse_version
#      12
#      13 _NUMPY_NAMESPACE_NAMES = {"numpy", "array_api_compat.numpy"}
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/fixes.py in <module>
#      22
#      23 try:
# ---> 24     import pandas as pd
#      25 except ImportError:
#      26     pd = None
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in <module>
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      48
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/api.py in <module>
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/__init__.py in <module>
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#
# pandas/_libs/interval.pyx in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-577655ad4442> in <cell line: 1>()
# ----> 1 from sklearn.preprocessing import LabelEncoder
#       2 import pandas as pd
#
# /usr/local/lib/python3.10/dist-packages/sklearn/__init__.py in <module>
#      82         _distributor_init,  # noqa: F401
#      83     )
# ---> 84     from .base import clone
#      85     from .utils._show_versions import show_versions
#      86
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in <module>
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/__init__.py in <module>
#       9 from . import _joblib, metadata_routing
#      10 from ._bunch import Bunch
# ---> 11 from ._chunking import gen_batches, gen_even_slices
#      12 from ._estimator_html_repr import estimator_html_repr
#      13
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_chunking.py in <module>
#       6
#       7 from .._config import get_config
# ----> 8 from ._param_validation import Interval, validate_params
#       9
#      10
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in <module>
#      12
#      13 from .._config import config_context, get_config
# ---> 14 from .validation import _is_arraylike_not_scalar
#      15
#      16
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in <module>
#      24 from .. import get_config as _get_config
#      25 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 26 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      27 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#      28 from ._isfinite import FiniteStatus, cy_isfinite
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in <module>
#       9
#      10 from .._config import get_config
# ---> 11 from .fixes import parse_version
#      12
#      13 _NUMPY_NAMESPACE_NAMES = {"numpy", "array_api_compat.numpy"}
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/fixes.py in <module>
#      22
#      23 try:
# ---> 24     import pandas as pd
#      25 except ImportError:
#      26     pd = None
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in <module>
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      48
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/api.py in <module>
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/__init__.py in <module>
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#
# pandas/_libs/interval.pyx in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
data =pd.read_csv("iris.csv",index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-716ee1931da8> in <cell line: 1>()
# ----> 1 data =pd.read_csv("iris.csv",index_col=0)
#
# NameError: name 'pd' is not defined

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-304fa4ce4ebd> in <cell line: 1>()
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
#Changes does not effect the "data" dataframe
data1=data.copy()

# %%
labelencoder = LabelEncoder()
data1.iloc[:, -1] = labelencoder.fit_transform(data1.iloc[:,-1])

# %%
data1

# %% [markdown]
# ### One Hot Encoder

# %% [markdown]
# #### Using sklearn

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
data2=pd.read_csv("iris.csv",index_col=0)

# %%
data2

# %%
# creating instance of one-hot-encoder
enc = OneHotEncoder(handle_unknown='ignore')

# %%
# passing bridge-types-cat column (label encoded values of bridge_types)
enc_df = pd.DataFrame(enc.fit_transform(data2[['Species']]).toarray())

# %%
enc_df

# %%
# merge with main df
data_final = data2.iloc[:,0:4].join(enc_df)
data_final

# iloc is used in join

# %% [markdown]
# #### Using Pandas

# %%
import pandas as pd

# %%
data3 =pd.read_csv("iris.csv",index_col=0)

# %%
data_encoded=pd.get_dummies(data3)

# %%
data_encoded

# %% [markdown]
# #### IsolationForest

# %%
from sklearn.ensemble import IsolationForest

# %%
data =pd.read_csv("iris.csv",index_col=0)
data_encoded=pd.get_dummies(data)

# %%
# training the model
clf = IsolationForest(random_state=10,contamination=.01)
clf.fit(data_encoded)

#  Categorical data
# contamination=.01 is an outlier  (mana eastam 0.01 value)

# %%
# predictions
y_pred_outliers = clf.predict(data_encoded)

# %%
#-1 for outliers and 1 for inliers.
y_pred_outliers

# %%
data_encoded

# %%
## Let us add a new data point which is outlier
data_encoded.loc[150]=[20,40,30,50,1,0,0]

# 150 row add data

# %%
data_encoded

# %%
# training the model
clf = IsolationForest(random_state=10,contamination=.01)
clf.fit(data_encoded)
# predictions
y_pred_outliers = clf.predict(data_encoded)
y_pred_outliers


# outlier = -1

# %%
data_encoded['scores']=clf.decision_function(data_encoded)

# decision_function ---> used in mathmatical calculation

# %%
data_encoded['anomaly']=clf.predict(data_encoded.iloc[:,0:7])

# %%
data_encoded

# %%
#Print the outlier data points

data_encoded[data_encoded['anomaly']==-1]

# %% [markdown]
# ### PPS score

# %%
#install the package
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import ppscore as pps

# %%
#pps.score(df, "feature_column", "target_column")  syntax
pps.score(data, "Sepal.Length", "Petal.Length")

# %%
import pandas as pd
data=pd.read_csv("iris.csv")

# %%
#calculate the whole PPS matrix
pps.matrix(data)
